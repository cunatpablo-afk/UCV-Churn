# %% [markdown]
# ## Hipotesis de partida
#
# Hipotesis H1:
# La tasa de churn no deberia ser uniforme entre tipos de plan.
#
# Hipotesis H2:
# Clientes con menor antiguedad podrian mostrar mayor propension al churn.
#
# Hipotesis H3:
# El churn podria diferir segun tipo de zona o region, porque el contexto territorial suele afectar la experiencia de servicio.
#
# Hipotesis H4:
# Variables proxy de valor, como `ingreso_estimado`, `num_lineas` o `descuento_activo`, pueden mostrar patrones diferenciales entre clientes que churnean y los que no.
#
# Hipotesis H5:
# El dataset puede contener problemas de calidad que alteren la lectura del churn si no se detectan antes.

# %% [markdown]
# ## 1. Carga del dataset
#
# Trabajamos con el fichero compartido para alumnado. El primer paso es cargarlo y revisar rapidamente su forma general.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Configuración visual
sns.set(style="whitegrid")
plt.rcParams["figure.figsize"] = (10,6)

# Cargar datos
df = pd.read_csv("C:\\Users\\cunat\\Desktop\\GIT\\UCV-Churn\\data\\raw\\clientes.csv")

# Vista inicial
print(df.head())
print(df.info())
print(df.describe())
# Out:
#   cliente_id zona_id  region       tipo_zona  poblacion_zona  edad sexo  \
# 0    C000001     Z26   Oeste  urbana_premium          107159  18.0    M
# 1    C000002     Z15   Oeste       suburbana           62939  54.0    M
# 2    C000003     Z27   Norte       suburbana           42704  54.0    M
# 3    C000004     Z22    Este       suburbana           53534  34.0    M
# 4    C000005     Z04  Centro       suburbana           55457  46.0    F
#
#   estado_civil  num_lineas tipo_plan tipo_dispositivo  ingreso_estimado  \
# 0    Soltero/a           2   Prepago        Gama alta            4335.0
# 1     Casado/a           2   Premium       Gama media            4609.0
# 2     Casado/a           3   Prepago        Gama baja            1836.0
# 3    Soltero/a           1   Prepago       Gama media            2318.0
# 4    Soltero/a           2  Contrato       Gama media            2184.0
#
#    antiguedad_meses  descuento_activo
# 0              72.0                 0
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))
sns.countplot(x="region", data=df, order=df["region"].value_counts().index)

plt.title("Distribución de clientes por región")
plt.xlabel("Región")
plt.ylabel("Número de clientes")
plt.xticks(rotation=45)

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))
sns.countplot(x="tipo_zona", data=df, order=df["tipo_zona"].value_counts().index)

plt.title("Distribución de clientes por tipo de zona")
plt.xlabel("Tipo de zona")
plt.ylabel("Número de clientes")
plt.xticks(rotation=45)

plt.show()

# %%
plt.figure(figsize=(8,5))
sns.histplot(df["edad"], bins=20, kde=True)

plt.title("Distribución de la edad")
plt.xlabel("Edad")
plt.ylabel("Frecuencia")

plt.show()

# %%
plt.figure(figsize=(8,5))
sns.countplot(x="estado_civil", data=df, order=df["estado_civil"].value_counts().index)

plt.title("Distribución de clientes por estado civil")
plt.xlabel("Estado civil")
plt.ylabel("Número de clientes")
plt.xticks(rotation=45)

plt.show()

# %%
plt.figure(figsize=(8,5))
sns.countplot(x="num_lineas", data=df, order=sorted(df["num_lineas"].unique()))

plt.title("Distribución del número de líneas por cliente")
plt.xlabel("Número de líneas")
plt.ylabel("Número de clientes")

plt.show()

# %%
plt.figure(figsize=(8,5))
sns.countplot(x="tipo_plan", data=df, order=df["tipo_plan"].value_counts().index)

plt.title("Distribución de clientes por tipo de plan")
plt.xlabel("Tipo de plan")
plt.ylabel("Número de clientes")
plt.xticks(rotation=45)

plt.show()

# %%
plt.figure(figsize=(8,5))
sns.countplot(x="tipo_dispositivo", data=df, order=df["tipo_dispositivo"].value_counts().index)

plt.title("Distribución de clientes por tipo de dispositivo")
plt.xlabel("Tipo de dispositivo")
plt.ylabel("Número de clientes")
plt.xticks(rotation=45)

plt.show()

# %%
plt.figure(figsize=(8,5))
sns.histplot(df["ingreso_estimado"], bins=30, kde=True)

plt.title("Distribución del ingreso estimado")
plt.xlabel("Ingreso estimado")
plt.ylabel("Frecuencia")

plt.show()
